# %%
import wget
import pandas as pd

# %%
wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
# Out:
#   Cell In[2], line 1
#     wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
#          ^
# SyntaxError: invalid syntax

# %%
spacex_launch_dash = wget.download("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv")
spacex_launch_dash_df=pd.read_csv(spacex_launch_dash)

# %%
wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/t4-Vy4iOU19i8y6E3Px_ww/spacex-dash-app.py"

# %%
import requests

url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/t4-Vy4iOU19i8y6E3Px_ww/spacex-dash-app.py"
resp = requests.get(url)
resp.raise_for_status()  # sorun varsa burada hata fırlatır

with open("spacex-dash-app.py", "wb") as fh:
    fh.write(resp.content)

print("Dosya indirildi: spacex-dash-app.py")
# Out:
# Dosya indirildi: spacex-dash-app.py
